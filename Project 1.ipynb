# %%
import pandas as pd
info = pd.read_csv("NMIS.csv")

# %%
info.head()
# Out:
#   maternal_health_delivery_services  \
# 0                              True
# 1                              True
# 2                              True
# 3                              True
# 4                              True
#
#                          facility_type_display management  \
# 0                                  Health Post     public
# 1                  Primary Health Centre (PHC)    private
# 2  Basic Health Centre / Primary Health Clinic     public
# 3                  Primary Health Centre (PHC)     public
# 4                                  Health Post     public
#
#    emergency_transport skilled_birth_attendant phcn_electricity c_section_yn  \
# 0                 True                   False             True        False
# 1                 True                    True             True        False
# 2                 True                    True             True         True
# 3                False                   False            False        False
# ...

# %%
info.tail()
# Out:
#       maternal_health_delivery_services  \
# 34134                              True
# 34135                              True
# 34136                             False
# 34137                             False
# 34138                             False
#
#                               facility_type_display management  \
# 34134                   Primary Health Centre (PHC)    private
# 34135  Basic Health Centre or Primary Health Clinic     public
# 34136                   Primary Health Centre (PHC)    private
# 34137                                    Dispensary     public
# 34138                   Primary Health Centre (PHC)     public
#
#        emergency_transport skilled_birth_attendant phcn_electricity  \
# 34134                 True                    True             True
# 34135                False                   False             True
# 34136                False                    True             True
# ...

# %%
info.shape
# Out:
# (34139, 20)

# %%
info.iloc[1,:]
# Out:
# maternal_health_delivery_services                           True
# facility_type_display                Primary Health Centre (PHC)
# management                                               private
# emergency_transport                                         True
# skilled_birth_attendant                                     True
# phcn_electricity                                            True
# c_section_yn                                               False
# child_health_measles_immun_calc                             True
# improved_water_supply                                      False
# improved_sanitation                                         True
# vaccines_fridge_freezer                                     True
# antenatal_care_yn                                           True
# family_planning_yn                                         False
# malaria_treatment_artemisinin                               True
# ...

# %%
info.iloc[:,1:]
# Out:
#                               facility_type_display   management  \
# 0                                       Health Post       public
# 1                       Primary Health Centre (PHC)      private
# 2       Basic Health Centre / Primary Health Clinic       public
# 3                       Primary Health Centre (PHC)       public
# 4                                       Health Post       public
# 5                                       Health Post      private
# 6                                       Health Post       public
# 7                               Specialist Hospital      private
# 8                               Specialist Hospital      private
# 9                                       Health Post      private
# 10                                      Health Post       public
# 11                              Specialist Hospital      private
# 12                              Specialist Hospital      private
# ...

# %%
info.loc[:,["maternal_health_delivery_services","facility_type_display","management"]]
# Out:
#       maternal_health_delivery_services  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
# 5                                  True
# 6                                 False
# 7                                  True
# 8                                  True
# 9                                  True
# 10                                 True
# 11                                 True
# 12                                 True
# 13                                  NaN
# 14                                False
# 15                                False
# 16                                False
# 17                                False
# 18                                 True
# 19                                False
# 20                                 True
# 21                                 True
# ...

# %%
maternal_info=(info["maternal_health_delivery_services"]== True) &(info["emergency_transport"]== True)
filter_info=info[maternal_info]
filter_info.head()
# Out:
#   maternal_health_delivery_services  \
# 0                              True
# 1                              True
# 2                              True
# 5                              True
# 7                              True
#
#                          facility_type_display management  \
# 0                                  Health Post     public
# 1                  Primary Health Centre (PHC)    private
# 2  Basic Health Centre / Primary Health Clinic     public
# 5                                  Health Post    private
# 7                          Specialist Hospital    private
#
#    emergency_transport skilled_birth_attendant phcn_electricity c_section_yn  \
# 0                 True                   False             True        False
# 1                 True                    True             True        False
# 2                 True                    True             True         True
# 5                 True                    True            False         True
# ...

# %%
info.corr()
# Out:
#                             emergency_transport  num_chews_fulltime  \
# emergency_transport                    1.000000            0.080771
# num_chews_fulltime                     0.080771            1.000000
# num_nurses_fulltime                    0.132180            0.029056
# num_nursemidwives_fulltime             0.115705            0.087474
# num_doctors_fulltime                   0.114978            0.066989
# latitude                              -0.159956            0.025038
# longitude                             -0.192402            0.074945
#
#                             num_nurses_fulltime  num_nursemidwives_fulltime  \
# emergency_transport                    0.132180                    0.115705
# num_chews_fulltime                     0.029056                    0.087474
# num_nurses_fulltime                    1.000000                    0.465188
# num_nursemidwives_fulltime             0.465188                    1.000000
# ...

# %%
info.count()
# Out:
# maternal_health_delivery_services    33451
# facility_type_display                34024
# management                           29385
# emergency_transport                  34139
# skilled_birth_attendant              33255
# phcn_electricity                     29781
# c_section_yn                         33578
# child_health_measles_immun_calc      29351
# improved_water_supply                29715
# improved_sanitation                  34071
# vaccines_fridge_freezer              29285
# antenatal_care_yn                    33473
# family_planning_yn                   33385
# malaria_treatment_artemisinin        33476
# num_chews_fulltime                   33705
# num_nurses_fulltime                  31643
# num_nursemidwives_fulltime           33166
# num_doctors_fulltime                 31974
# latitude                             34139
# longitude                            34139
# dtype: int64

# %%
info.dropna()
# Out:
#       maternal_health_delivery_services  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
# 5                                  True
# 6                                 False
# 7                                  True
# 9                                  True
# 10                                 True
# 11                                 True
# 12                                 True
# 15                                False
# 16                                False
# 17                                False
# 18                                 True
# 19                                False
# 20                                 True
# 21                                 True
# 23                                False
# 24                                 True
# 25                                 True
# ...

# %%
maternal_info=(info["maternal_health_delivery_services"] == False)&(info["management"] == "private")
filter_info=info[maternal_info]
filter_info.tail()
# Out:
#       maternal_health_delivery_services  \
# 33921                             False
# 34039                             False
# 34061                             False
# 34070                             False
# 34136                             False
#
#                               facility_type_display management  \
# 33921                           Specialist Hospital    private
# 34039                   Primary Health Centre (PHC)    private
# 34061  Basic Health Centre or Primary Health Clinic    private
# 34070                   Primary Health Centre (PHC)    private
# 34136                   Primary Health Centre (PHC)    private
#
#        emergency_transport skilled_birth_attendant phcn_electricity  \
# 33921                False                    True             True
# 34039                 True                    True             True
# 34061                False                    True             True
# ...

# %%
info.count()
# Out:
# maternal_health_delivery_services    33451
# facility_type_display                34024
# management                           29385
# emergency_transport                  34139
# skilled_birth_attendant              33255
# phcn_electricity                     29781
# c_section_yn                         33578
# child_health_measles_immun_calc      29351
# improved_water_supply                29715
# improved_sanitation                  34071
# vaccines_fridge_freezer              29285
# antenatal_care_yn                    33473
# family_planning_yn                   33385
# malaria_treatment_artemisinin        33476
# num_chews_fulltime                   33705
# num_nurses_fulltime                  31643
# num_nursemidwives_fulltime           33166
# num_doctors_fulltime                 31974
# latitude                             34139
# longitude                            34139
# dtype: int64

# %%
info["num_doctors_fulltime"].tail()
# Out:
# 34134    1.0
# 34135    0.0
# 34136    1.0
# 34137    0.0
# 34138    0.0
# Name: num_doctors_fulltime, dtype: float64

# %%
info.max()
# Out:
# maternal_health_delivery_services       True
# emergency_transport                     True
# skilled_birth_attendant                 True
# phcn_electricity                        True
# c_section_yn                            True
# child_health_measles_immun_calc         True
# improved_water_supply                   True
# improved_sanitation                     True
# vaccines_fridge_freezer                 True
# antenatal_care_yn                       True
# family_planning_yn                      True
# malaria_treatment_artemisinin           True
# num_chews_fulltime                        80
# num_nurses_fulltime                      513
# num_nursemidwives_fulltime               431
# num_doctors_fulltime                     378
# latitude                              13.865
# longitude                            14.6364
# dtype: object

# %%
maternal_info=(info["skilled_birth_attendant" ] == True) & (info["num_nursemidwives_fulltime"] > 10)
filter_info=info[maternal_info]
filter_info.head(20)
# Out:
#      maternal_health_delivery_services  \
# 2                                 True
# 7                                 True
# 37                                True
# 53                               False
# 62                                True
# 71                                True
# 213                               True
# 229                               True
# 296                               True
# 304                               True
# 389                               True
# 420                               True
# 1251                              True
# 1413                              True
# 1445                              True
# 1559                              True
# 1860                             False
# 2158                              True
# 2699                              True
# 2856                              True
#
#                             facility_type_display   management  \
# 2     Basic Health Centre / Primary Health Clinic       public
# ...
